# %% [markdown]
# <a href="https://colab.research.google.com/github/sbj6364/voice-converter/blob/main/01_voice_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1번 : 음성 데이터 살펴보기
#
# 음성은 사람이 발성기관을 통해 내는 소리를 의미합니다. 넓은 의미의 음성에는 말소리, 노래와 같은 언어적 음성 뿐만 아니라 웃음소리, 기침 소리 같은 비언어적 음성이 포함됩니다. 본 튜토리얼에서는 언어적 음성, 그 중에서도 일반적인 대화에서 사용되는 음성을 중점적으로 살펴봅니다.
#
# librosa 및 maplotlib 라이브러리를 활용해 아래의 speech wav음원을 다운로드 해 불러 온 뒤, 해당 음원의 파형과 spectrogram을 함께 그려 출력하는 코드를 작성하세요.
#
#
# #### 베이스라인
# ~~~python
# import numpy as np
# import librosa
# import matplotlib
# matplotlib.use("Agg")
# import matplotlib.pyplot as plt
# import librosa.display
#
# audio, sr = ''' code here '''
# spectrogram = ''' code here '''
#
# plt.figure(figsize=(16,9))
# plt.subplot(2,1,1)
# plt.plot(audio)
# plt.xlim([0,len(audio)])
# plt.title('waveform')
# plt.subplot(2,1,2)
# librosa.display.specshow(spectrogram)
# plt.title('spectrogram')
# plt.tight_layout()
# plt.savefig('example1_output.png')
# plt.close()
# ~~~

# %%
import numpy as np  
import librosa
import matplotlib 
matplotlib.use("Agg")
import matplotlib.pyplot as plt 
import librosa.display

# %%
def Spectrogram(wav):
		stft = librosa.stft(wav)
		stft = np.abs(stft)
		return stft

# %%
audio, sr = librosa.load('speech.wav', sr=None)
spectrogram = np.log(Spectrogram(audio)+1e-5)

plt.figure(figsize=(16,9))
plt.subplot(2,1,1)
plt.plot(audio)
plt.xlim([0,len(audio)])
plt.title('waveform')
plt.subplot(2,1,2)
librosa.display.specshow(spectrogram)
plt.title('spectrogram')
plt.tight_layout()
plt.savefig('example1_output.png')
# plt.close()
